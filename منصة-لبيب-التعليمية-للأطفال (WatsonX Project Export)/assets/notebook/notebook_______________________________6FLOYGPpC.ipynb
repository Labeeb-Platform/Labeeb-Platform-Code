# %%
   import pandas as pd

# %%
   import pandas as pd

# %%
   import nltk

# %%
   nltk.download('punkt')  # For text processing
# Out:
# [nltk_data] Downloading package punkt to /home/wsuser/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
   def main_menu():
       print("اختر خياراً:")
       print("1. تقييم القصة")  # Evaluate the story
       print("2. كتابة القصة")  # Write a story
       choice = input("أدخل 1 أو 2: ")
       if choice == '1':
           evaluate_my_story()
       elif choice == '2':
           write_a_story()
       else:
           print("خيار غير صحيح. حاول مرة أخرى.")
           main_menu()

# %%
                    story_text = input("Please enter the story text (up to 1,000 words): ")
                    
                    # Check if the story text exceeds the word limit
                    if len(story_text.split()) > 1000:
                        print("Story exceeds the 1,000-word limit. Please shorten the story.")
                    else:
                        # Call the prompt template named 'rubric' to evaluate the story
                        result = rubric(story_text)   
                    
                        # Print the evaluation result on screen
                        print("\nEvaluation Results:")
                        print(result)
                       def write_a_story():
                           character_name = input("أدخل اسم الشخصية الرئيسية: ")
                           gender = input("حدد جنس الشخصية (ذكر/أنثى): ")
                           value_to_teach = input("حدد القيمة التي ترغب في تعليمها: ")
                           places = ["المنزل", "المدرسة", "المتجر", "الشاطئ", "الحديقة"]
                           print(f"اختر المكان: {', '.join(places)}")
                           place = input("أدخل المكان المختار: ")
                    
                    
                    def write_story():
                        # Ask for character details
                        character_name = input("أدخل اسم الشخصية الرئيسية: ")
                        gender = input("حدد جنس الشخصية (ذكر/أنثى): ")
                        value_to_teach = input("حدد القيمة التي ترغب في تعليمها: ")
                        
                        # List of places
                        places = ["المنزل", "المدرسة", "المتجر", "الشاطئ", "الحديقة"]
                        print(f"اختر المكان: {', '.join(places)}")
                        place = input("أدخل المكان المختار: ")
                        
                        # Ask for an event description
                        event = input("اكتب وصفًا للحدث (مثال: رحلة فضائية من السعودية إلى الفضاء): ")
                    
                        # Construct the prompt input based on provided details
                        story_input = {
                            "character_name": character_name,
                            "gender": gender,
                            "value_to_teach": value_to_teach,
                            "place": place,
                            "event": event
                        }
                    
                        # Call the prompt template to generate the story
                        story = prompt_two_branches(story_input)  # Assuming prompt_two_branches accepts a dictionary input
                    
                        # Print the generated story
                        print("\nالقصة المكتوبة:")
                        print(story)
                    ```
# Out:
#   File <tokenize>:13
#     def write_a_story():
#     ^
# IndentationError: unindent does not match any outer indentation level
